# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
from pymongo import MongoClient
import pandas as pd
from pprint import pprint as pp

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
#List of Databases
mongo.list_database_names()
# Out:
# ['admin',
#  'classDB',
#  'config',
#  'june2024_db',
#  'lecture12',
#  'local',
#  'mechanics',
#  'met',
#  'test',
#  'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
db.list_collection_names()
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Count Documents
establishments.count_documents({"scores.Hygiene": 20})
# Out:
# 41

# %%
query = {"scores.Hygiene": 20}

fields = {}

limit = 50

results = establishments.find(query, fields).limit(limit)

pp(results[0])
# Out:
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66786ba24654f09b21155d27'),
#  'geocode': {'latitude': Decimal128('50.769705'),
#              'longitude': Decimal128('0.27694')},
# ...

# %%
#print the number of rows in the DataFrame
Hygiene_df = pd.DataFrame(results)

# %%
Hygiene_df.head(2)
# Out:
#                         _id  FHRSID  ChangesByServerID  \
# 0  66786ba24654f09b21155d27  110681                  0
# 1  66786ba24654f09b211560a8  612039                  0
#
#   LocalAuthorityBusinessID         BusinessName     BusinessType  \
# 0                     4029  The Chase Rest Home  Caring Premises
# 1                1970/FOOD           Brenalwood  Caring Premises
#
#    BusinessTypeID          AddressLine1        AddressLine2 AddressLine3  ...  \
# 0               5  5-6 Southfields Road          Eastbourne  East Sussex  ...
# 1               5             Hall Lane  Walton-on-the-Naze        Essex  ...
#
#                       LocalAuthorityWebSite       LocalAuthorityEmailAddress  \
# 0  http://www.eastbourne.gov.uk/foodratings  Customerfirst@eastbourne.gov.uk
# 1             http://www.tendringdc.gov.uk/       fhsadmin@tendringdc.gov.uk
#
#                                               scores  SchemeType  \
# ...

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query = {"LocalAuthorityName":{"$regex":"London"},"RatingValue":{"$gte":4}}

fields = {}


limit = 5

results1 = establishments.find(query, fields)
results1 = pd.json_normalize(results1)
results1.head(3)
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  66786ba24654f09b21157740   621707                  0
# 1  66786ba24654f09b21157a67  1130836                  0
# 2  66786ba24654f09b211585b3   293783                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0             PI/000025307                  Charlie's
# 1             PI/000034075    Mv City Cruises Erasmus
# 2             PI/000002614  Benfleet Motor Yacht Club
#
#               BusinessType  BusinessTypeID  \
# 0  Other catering premises            7841
# 1  Other catering premises            7841
# 2  Other catering premises            7841
#
#                                  AddressLine1  \
# 0  Oak Apple Farm Building 103 Sheernes Docks
# 1                          Cherry Garden Pier
# 2                                  Ferry Road
#
#                        AddressLine2 AddressLine3  ...  geocode.longitude  \
# ...

# %%
# Use count_documents to display the number of documents in the result
establishments.count_documents({"LocalAuthorityName":{"$regex":"London"},"RatingValue":{"$gte":4}})
# Out:
# 33

# %%
# Display the first document in the results using pprint
pp(establishments.find_one({"LocalAuthorityName":{"$regex":"London"},"RatingValue":{"$gte":4}}))
# Out:
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66786ba24654f09b21157740'),
#  'geocode': {'latitude': Decimal128('51.369321'),
#              'longitude': Decimal128('0.508551')},
# ...

# %%
# Convert the result to a Pandas DataFrame
results1_df = pd.DataFrame(results1)

# %%
# Display the number of rows in the DataFrame
results1_df.shape[0]
# Out:
# 33

# %%
# Display the first 10 rows of the DataFrame
results1_df.head(10)
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  66786ba24654f09b21157740   621707                  0
# 1  66786ba24654f09b21157a67  1130836                  0
# 2  66786ba24654f09b211585b3   293783                  0
# 3  66786ba24654f09b211593b3   294474                  0
# 4  66786ba24654f09b211593b4  1315095                  0
# 5  66786ba24654f09b21159abe   294900                  0
# 6  66786ba24654f09b2115bbca   293756                  0
# 7  66786ba24654f09b2115bf8f   878523                  0
# 8  66786ba24654f09b2115bfab   293772                  0
# 9  66786ba24654f09b2115bfac   294606                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000025307                             Charlie's
# 1             PI/000034075               Mv City Cruises Erasmus
# 2             PI/000002614             Benfleet Motor Yacht Club
# 3             PI/000014647              Tilbury Seafarers Centre
# ...

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
lat = 51.49014200
long = 0.08384000

query = {"RatingValue":5,
         "geocode.longitude":{"$gte":long - degree_search,"$lte":long + degree_search},
         "geocode.latitude":{"$gte":lat - degree_search,"$lte":lat + degree_search}}


fields={}

sort =  [("scores.Hygiene")]

limit = 5

results2 = establishments.find(query, fields).sort(sort).limit(limit)
[pp(x) for x in results2]
# Out:
# {'AddressLine1': '130 - 132 Plumstead High Street',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Volunteer',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4646.965634598608,
#  'FHRSID': 694609,
#  'LocalAuthorityBusinessID': 'PI/000116619',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1JQ',
#  'RatingDate': '2019-08-05T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66786ba24654f09b2115b584'),
#  'geocode': {'latitude': Decimal128('51.4873437'),
#              'longitude': Decimal128('0.09208')},
# ...

# %%
results2 = establishments.find(query, fields).sort(sort).limit(limit)
geo_results_df = pd.json_normalize(results2)

# %%
# Convert result to Pandas DataFrame
geo_results_df
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  66786ba24654f09b2115b584   694609                  0
# 1  66786ba24654f09b2115b59c   695241                  0
# 2  66786ba24654f09b2115b5b9   694482                  0
# 3  66786ba24654f09b2115b557   695223                  0
# 4  66786ba24654f09b2115b566  1380578                  0
#
#   LocalAuthorityBusinessID                         BusinessName  \
# 0             PI/000116619                            Volunteer
# 1             PI/000179088              Plumstead Manor Nursery
# 2             PI/000086551                               Greggs
# 3             PI/000178842                              Iceland
# 4                    14425  Howe and Co Fish and Chips - Van 17
#
#                             BusinessType  BusinessTypeID  \
# 0                      Pub/bar/nightclub            7843
# 1                        Caring Premises               5
# 2                 Takeaway/sandwich shop            7844
# ...

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that:
# 1. Matches establishments with a hygiene score of 0
match_query = {"$match":{"scores.Hygiene":0}}

# 2. Groups the matches by Local Authority
group_query = {
    "$group":{"_id":"$LocalAuthorityName",
              "count":{"$sum":1}}}

# 3. Sorts the matches from highest to lowest
sort_values = {"$sort":{"count":-1}}


pipeline = [match_query, group_query, sort_values] 

results3 = establishments.aggregate(pipeline)

pipeline_rslts = []

[pipeline_rslts.append(x) for x in results3]

pipeline_rslts
# Out:
# [{'_id': 'Thanet', 'count': 1130},
#  {'_id': 'Greenwich', 'count': 882},
#  {'_id': 'Maidstone', 'count': 713},
#  {'_id': 'Newham', 'count': 711},
#  {'_id': 'Swale', 'count': 686},
#  {'_id': 'Chelmsford', 'count': 680},
#  {'_id': 'Medway', 'count': 672},
#  {'_id': 'Bexley', 'count': 607},
#  {'_id': 'Southend-On-Sea', 'count': 586},
#  {'_id': 'Tendring', 'count': 542},
#  {'_id': 'Colchester', 'count': 498},
#  {'_id': 'Tunbridge Wells', 'count': 491},
#  {'_id': 'Folkestone and Hythe', 'count': 480},
#  {'_id': 'Eastbourne', 'count': 478},
#  {'_id': 'Hastings', 'count': 464},
#  {'_id': 'Bromley', 'count': 460},
#  {'_id': 'Ashford', 'count': 427},
#  {'_id': 'Havering', 'count': 397},
#  {'_id': 'Dartford', 'count': 383},
#  {'_id': 'Braintree', 'count': 382},
#  {'_id': 'Basildon', 'count': 362},
#  {'_id': 'Gravesham', 'count': 339},
#  {'_id': 'Tonbridge and Malling', 'count': 325},
#  {'_id': 'Thurrock', 'count': 313},
#  {'_id': 'Barking and Dagenham', 'count': 301},
# ...

# %%
# Print the number of documents in the result
len(pipeline_rslts)
# Out:
# 55

# %%
# Print the first 10 results
pipeline_rslts[:10]
# Out:
# [{'_id': 'Thanet', 'count': 1130},
#  {'_id': 'Greenwich', 'count': 882},
#  {'_id': 'Maidstone', 'count': 713},
#  {'_id': 'Newham', 'count': 711},
#  {'_id': 'Swale', 'count': 686},
#  {'_id': 'Chelmsford', 'count': 680},
#  {'_id': 'Medway', 'count': 672},
#  {'_id': 'Bexley', 'count': 607},
#  {'_id': 'Southend-On-Sea', 'count': 586},
#  {'_id': 'Tendring', 'count': 542}]

# %%
# Convert the result to a Pandas DataFrame
pipeline_rslts = pd.DataFrame(pipeline_rslts)

# %%
# Display the number of rows in the DataFrame
pipeline_rslts.shape[0]
# Out:
# 55

# %%
# Display the first 10 rows of the DataFrame
pipeline_rslts.head(10)
# Out:
#                _id  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542
